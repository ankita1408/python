# %% [markdown]
# ## Read json to csv

# %%
data = '{"employee_name":"james", "email":"james@gmail.com", "job_profile":[{"title1":"team lead", "title":"sr.developer"}]}'
pd.read_json(data)

# %%
data
# Out:
# '{"employee_name":"james", "email":"james@gmail.com", "job_profile":[{"title1":"team lead", "title":"sr.developer"}]}'

# %%
import pandas as pd

json = pd.read_json('https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/data.json')

# %%
json
# Out:
#     integer            datetime  category
# 0         5 2015-01-01 00:00:00         0
# 1         5 2015-01-01 00:00:01         0
# 2         9 2015-01-01 00:00:02         0
# 3         6 2015-01-01 00:00:03         0
# 4         6 2015-01-01 00:00:04         0
# ..      ...                 ...       ...
# 95        9 2015-01-01 00:01:35         0
# 96        8 2015-01-01 00:01:36         0
# 97        6 2015-01-01 00:01:37         0
# 98        8 2015-01-01 00:01:38         0
# 99        1 2015-01-01 00:01:39         0
#
# [100 rows x 3 columns]

# %%
## read HTML content

# %%
url='https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/'

# %%
df1=pd.read_html(url)

# %%
df1
# Out:
# [                         Bank NameBank           CityCity StateSt  CertCert  \
#  0                  First Republic Bank      San Francisco      CA     59017
#  1                       Signature Bank           New York      NY     57053
#  2                  Silicon Valley Bank        Santa Clara      CA     24735
#  3                    Almena State Bank             Almena      KS     15426
#  4           First City Bank of Florida  Fort Walton Beach      FL     16748
#  ..                                 ...                ...     ...       ...
#  561                 Superior Bank, FSB           Hinsdale      IL     32646
#  562                Malta National Bank              Malta      OH      6629
#  563    First Alliance Bank & Trust Co.         Manchester      NH     34264
#  564  National State Bank of Metropolis         Metropolis      IL      3815
#  565                   Bank of Honolulu           Honolulu      HI     21029
#
# ...

# %%
pip install lxml html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install lxml html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/win-64::aiohttp==3.8.1=py39hb82d6ee_1
#   - defaults/win-64::anaconda==custom=py39_1
#   - defaults/win-64::anaconda-navigator==2.2.0=py39haa95532_0
#   - conda-forge/noarch::async-timeout==4.0.2=pyhd8ed1ab_0
#   - defaults/noarch::black==19.10b0=py_0
#   - defaults/noarch::bleach==4.0.0=pyhd3eb1b0_0
#   - defaults/noarch::conda-token==0.3.0=pyhd3eb1b0_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/noarch::dask-core==2021.10.0=pyhd3eb1b0_0
#   - conda-forge/noarch::datashader==0.14.1=pyh6c4a22f_1
#   - defaults/win-64::distributed==2021.10.0=py39haa95532_0
#   - conda-forge/noarch::google-api-core==2.8.2=pyhd8ed1ab_0
#   - conda-forge/noarch::google-auth==2.9.0=pyh6c4a22f_0
#   - conda-forge/noarch::google-cloud-core==2.3.1=pyhd8ed1ab_0
# ...

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/COVID-19_pandemic', index_col=0)

# %%
df
# Out:
# [                                                                                  COVID-19 pandemic.1
#  COVID-19 pandemic
#  Medical professionals treating a COVID-19 patie...  Medical professionals treating a COVID-19 pati...
#  Confirmed deaths per 100,000 populationas of 19...  Confirmed deaths per 100,000 populationas of 1...
#  Cases per capita Cumulative percentage of popul...  Cases per capita Cumulative percentage of popu...
#  Cases per capita                                                                     Cases per capita
#  NaN                                                                                               NaN
#  Cumulative percentage of population infectedas ...  Cumulative percentage of population infectedas...
#  Disease                                                           Coronavirus disease 2019 (COVID-19)
#  Virus strain                                        Severe acute respiratory syndromecoronavirus 2...
# ...

# %% [markdown]
# ## Pickling
# ###### all pandas objects are equipped with to_pickle methods which use python's cpickle module to save data structure to disk using the pickle format

# %%
original_df = pd.DataFrame({"f1": range(6), "b1": range(6, 12)})
original_df
# Out:
#    f1  b1
# 0   0   6
# 1   1   7
# 2   2   8
# 3   3   9
# 4   4  10
# 5   5  11

# %%
d=original_df.to_pickle("./dummy.pkl")
d

# %%
unpickled_df = pd.read_pickle("./dummy.pkl")
unpickled_df
# Out:
#    f1  b1
# 0   0   6
# 1   1   7
# 2   2   8
# 3   3   9
# 4   4  10
# 5   5  11
